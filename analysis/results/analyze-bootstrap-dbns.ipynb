# %%
import pickle as pkl
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
omega0 = pkl.load(open('bootstrap-dbns-omega-0.25.p', 'rb'))

# %%
len(omega0['mf_be'])
# Out:
# 6

# %%
for t in [0, 3, 5]:
    plt.hist(omega0['mb_be'][t])
    plt.hist(omega0['mf_be'][t])
    plt.show()
